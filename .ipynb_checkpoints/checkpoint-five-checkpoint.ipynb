# %% [markdown]
# # Checkpoint Five: Modeling Data
#
# With your visualizations ready to go, the final step in your project is to do some predictive analysis on your dataset. You will be using linear regression for your model. You will not be penalized if your linear regression model does not work out. You just need to build the model and make notes as to the results.
#
# Link to my dataset: https://www.kaggle.com/datasets/danield2255/data-on-songs-from-billboard-19992019
#
# ## Prepare Your Dataframe
#
# Import any libraries you need and create a dataframe.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sb
import datetime as dt
from scipy.stats import linregress

song_rank_data=pd.read_csv('../cleaning-data-checkpoint_final.3/song_rank_data.csv')

# %% [markdown]
# ## Find Correlations
#
# Use either pairplot or a heatmap or both to find the two variables with the strongest correlation in your dataset.

# %%
song_rank_data.head()
# Out:
#    Unnamed: 0                     Name       Artists  Year  Debut.rank  \
# 0           0       '03 Bonnie & Clyde           Jay  2002          56
# 1           1         ...Ready For It?  Taylor Swift  2017           4
# 2           2  0 To 100 / The Catch Up         Drake  2014          63
# 3           3                        1           800  2017          61
# 4           4                  1 Thing        Amerie  2005         100
#
#    Peak.position  Weeks.to.peak  Weeks.at.peak  Lowest.rank  Weeks.to.low  \
# 0            4.0           10.0              3           56           1.0
# 1            4.0            1.0              1           96          19.0
# 2           35.0            7.0              4           64          20.0
# 3            3.0           20.0              4           68           7.0
# 4            8.0           11.0              1          100           1.0
#
#    Ending.rank  Total.weeks.on
# 0           46            23.0
# ...

# %%
sb.pairplot(song_rank_data)

# %%
sb.heatmap(song_rank_data.corr(), annot = True)
plt.show()

# %% [markdown]
# ## Create Your Model
#
# Use the two columns with the strongest correlation to create and train your model. Make sure to print out the summary and plot the column values and the line produced by the model.

# %%
x = song_rank_data['Peak.position']
y = song_rank_data['Total.weeks.on']

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, train_size = 0.7,
                                                   test_size = 0.3, random_state = 100)



x_train
# Out:
# 4881    53.0
# 3356    58.0
# 718     20.0
# 314     28.0
# 309     16.0
#         ...
# 1890    60.0
# 350     72.0
# 79      77.0
# 3927    22.0
# 5640    73.0
# Name: Peak.position, Length: 4130, dtype: float64

# %%
y_train
# Out:
# 4881    19.0
# 3356    16.0
# 718     21.0
# 314     20.0
# 309     20.0
#         ...
# 1890    11.0
# 350      2.0
# 79       2.0
# 3927    21.0
# 5640     2.0
# Name: Total.weeks.on, Length: 4130, dtype: float64

# %%
import statsmodels.api as sm

x_train_sm = sm.add_constant(x_train)


lr = sm.OLS(y_train, x_train_sm).fit()

lr.params
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# const            26.439557
# Peak.position    -0.244970
# dtype: float64

# %%
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:         Total.weeks.on   R-squared:                       0.446
# Model:                            OLS   Adj. R-squared:                  0.446
# Method:                 Least Squares   F-statistic:                     3327.
# Date:                Wed, 31 Aug 2022   Prob (F-statistic):               0.00
# Time:                        17:44:47   Log-Likelihood:                -14285.
# No. Observations:                4130   AIC:                         2.857e+04
# Df Residuals:                    4128   BIC:                         2.859e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
plt.scatter(x_train, y_train)

plt.plot(x_train, 26.439 + -0.245*x_train, 'r')

plt.show()

# %% [markdown]
# ## Error Terms
#
# Finally, plot your error terms!

# %%
r_sqr=r**2
print(r_sqr)
# Out:
# 0.4389195443084171

# %%
y_train_pred = lr.predict(x_train_sm)

res = (y_train - y_train_pred)

# %%
fig = plt.figure()

sb.distplot(res, bins = 15)
plt.title('Error Terms', fontsize = 15)
plt.xlabel('y_train - y_train_pred', fontsize=15)
plt.show()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Summarize Your Work
#
# Make notes of your answers to the questions below.
#
# 1. What was your R-squared value? .4389
# 2. Based on your results, do you think a linear regression model was the best type of predictive analysis for your dataset? It was somewhat predictive
# 3. Was your plot of the error terms a bell curve? yes
